# %%
import numpy as np
import openpyxl
import pandas as pd

workbook = openpyxl.Workbook()
sheet = workbook.active

data = [
    ['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'],
    ['BASHEER', 'PYTHON', 22, 'HYD', 120000, 3],
    ['SAIDA', 'DS', 21, 'BNG', 223844, 2],
    ['PRIYA', 'DA', 21, 'CHE', 349032, 5],
    ['JUBAIR', 'JAVA', 20, 'PUNE', 21328, 6],
    ['AJAY', 'SQL', 26, 'MUMBAI', 13124, 9]
]

for row in data:
    sheet.append(row)

workbook.save('data.xlsx')

# %%
data
# Out:
# [['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'],
#  ['BASHEER', 'PYTHON', 22, 'HYD', 120000, 3],
#  ['SAIDA', 'DS', 21, 'BNG', 223844, 2],
#  ['PRIYA', 'DA', 21, 'CHE', 349032, 5],
#  ['JUBAIR', 'JAVA', 20, 'PUNE', 21328, 6],
#  ['AJAY', 'SQL', 26, 'MUMBAI', 13124, 9]]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Jan Saida'

# %%
emp = pd.read_excel(r'C:\\Users\\Jan Saida\data.xlsx')

# %%
emp.shape
# Out:
# (5, 6)

# %%
emp.columns
# Out:
# Index(['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'], dtype='object')

# %%
len(emp.columns)
# Out:
# 6

# %%
len(emp)
# Out:
# 5

# %%
emp
# Out:
#       NAME  DOMAIN  AGE LOCATION  SALARY  EXP
# 0  BASHEER  PYTHON   22      HYD  120000    3
# 1    SAIDA      DS   21      BNG  223844    2
# 2    PRIYA      DA   21      CHE  349032    5
# 3   JUBAIR    JAVA   20     PUNE   21328    6
# 4     AJAY     SQL   26   MUMBAI   13124    9

# %%
emp['SALARY']
# Out:
# 0    120000
# 1    223844
# 2    349032
# 3     21328
# 4     13124
# Name: SALARY, dtype: int64

# %%
emp[['SALARY', 'EXP']]
# Out:
#    SALARY  EXP
# 0  120000    3
# 1  223844    2
# 2  349032    5
# 3   21328    6
# 4   13124    9

# %%
import numpy as np #ND ARRAY
import matplotlib.pyplot as plt #VISUALIZATION
import seaborn as sns #STATISTIC VISUALIZATION

# %%
vis1 = sns.displot(emp['SALARY'])

# %%
vis2 = sns.distplot(emp['SALARY'])
# Out:
# C:\Users\Jan Saida\AppData\Local\Temp\ipykernel_8932\826855712.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis2 = sns.distplot(emp['SALARY'])

# %%
vis3 = plt.hist(emp['SALARY'])

# %%
emp
# Out:
#       NAME  DOMAIN  AGE LOCATION  SALARY  EXP
# 0  BASHEER  PYTHON   22      HYD  120000    3
# 1    SAIDA      DS   21      BNG  223844    2
# 2    PRIYA      DA   21      CHE  349032    5
# 3   JUBAIR    JAVA   20     PUNE   21328    6
# 4     AJAY     SQL   26   MUMBAI   13124    9

# %%
plt.rcParams['figure.figsize'] = 2,1

# %%
vis4 = sns.lmplot(data=emp, x = 'EXP', y = 'SALARY')

# %%
 vis5 = sns.lmplot(data=emp, x = 'EXP', y = 'SALARY', fit_reg = False)

# %%
 vis6 = sns.lmplot(data=emp, x = 'EXP', y = 'SALARY', fit_reg = True)
